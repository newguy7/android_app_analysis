# %%
# Analyse the Android App Store Data

import pandas as pd

# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %%
df_apps = pd.read_csv('apps.csv')

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# 0   July 28, 2017          4.1 and up
# 1  April 15, 2016          3.0 and up
# 2   July 11, 2018          4.2 and up
# 3   June 28, 2018  Varies with device
# 4  August 6, 2018          4.1 and up

# %%
# randomly select 5 rows from Pandas DataFrame
df_apps.sample(n=5)
# Out:
#                                                   App         Category  \
# 1802                        Dialer theme G Black Gold  PERSONALIZATION
# 7949                      Learn to code with el Chavo           FAMILY
# 10201  Hotspot Shield Free VPN Proxy & Wi-Fi Security            TOOLS
# 4231   Bixby Button Remapper - bxActions Pro / Coffee            TOOLS
# 3401                    Learn Artificial Intelligence           FAMILY
#
#        Rating  Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 1802     4.20       33      0.84         500  Paid  $1.49       Everyone
# 7949     3.90     5933     60.00   1,000,000  Free      0       Everyone
# 10201    4.20  1116393      8.20  50,000,000  Free      0       Everyone
# 4231     3.90      319      0.02      10,000  Paid  $2.99       Everyone
# 3401     4.60       27      4.20      10,000  Free      0       Everyone
#
#                 Genres     Last_Updated Android_Ver
# 1802   Personalization  January 1, 2016  4.0 and up
# 7949       Educational   March 27, 2018  4.1 and up
# 10201            Tools   August 6, 2018  4.1 and up
# 4231             Tools   April 28, 2017  7.0 and up
# 3401         Education    July 14, 2018  4.1 and up

# %%
# By specifying the column axis (axis='columns'), the drop() method removes the specified column
# By specifying the row axis (axis='index'), the drop() method removes the specified row.
# drop columns Last_updated and Android_Version
updated_df = df_apps.drop(['Last_Updated','Android_Ver'], axis='columns')
updated_df.shape
# Out:
# (10841, 10)

# %%
updated_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
# dropping the rows having NaN values
df_apps_clean = updated_df.dropna()
 
# To reset the indices
df_apps_clean = df_apps_clean.reset_index(drop=True)

# %%
df_apps_clean
# Out:
#                                                   App Category  Rating  \
# 0                                 KBA-EZ Health Guide  MEDICAL    5.00
# 1                                            Ra Ga Ba     GAME    5.00
# 2                                             Mu.F.O.     GAME    5.00
# 3                                    Brick Breaker BR     GAME    5.00
# 4     Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00
# ...                                               ...      ...     ...
# 9362                                   Subway Surfers     GAME    4.50
# 9363                                   Subway Surfers     GAME    4.50
# 9364                                   Subway Surfers     GAME    4.50
# 9365                                   Subway Surfers     GAME    4.50
# 9366                                   Subway Surfers     GAME    4.50
#
#        Reviews  Size_MBs       Installs  Type  Price Content_Rating   Genres
# 0            4     25.00              1  Free      0       Everyone  Medical
# 1            2     20.00              1  Paid  $1.49       Everyone   Arcade
# 2            2     16.00              1  Paid  $0.99       Everyone   Arcade
# 3            7     19.00              5  Free      0       Everyone   Arcade
# 4            1      4.60              5  Free      0       Everyone  Medical
# ...        ...       ...            ...   ...    ...            ...      ...
# 9362  27723193     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 9363  27724094     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 9364  27725352     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 9365  27725352     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
# 9366  27711703     76.00  1,000,000,000  Free      0   Everyone 10+   Arcade
#
# [9367 rows x 10 columns]

# %%
df_apps_clean.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size_MBs          0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# dtype: int64

# %%
#Check for duplicate
df_apps_clean.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9362    False
# 9363    False
# 9364    False
# 9365     True
# 9366    False
# Length: 9367, dtype: bool

# %%
# Check if any duplicate values
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
print(duplicated_rows)
duplicated_rows.head()
# Out:
#                                              App            Category  Rating  \
# 212                       420 BZ Budeze Delivery             MEDICAL    5.00
# 281                                  MouseMingle              DATING    2.70
# 308   Cardiac diagnosis (heart rate, arrhythmia)             MEDICAL    4.40
# 327                                 Sway Medical             MEDICAL    5.00
# 335               Chat Kids - Chat Room For Kids              DATING    4.70
# ...                                          ...                 ...     ...
# 9328               Skype - free IM & video calls       COMMUNICATION    4.10
# 9335                                   Instagram              SOCIAL    4.50
# 9352                                Google Drive        PRODUCTIVITY    4.40
# 9358                                 Google News  NEWS_AND_MAGAZINES    3.90
# 9365                              Subway Surfers                GAME    4.50
#
#        Reviews  Size_MBs       Installs  Type   Price Content_Rating  \
# 212          2     11.00            100  Free       0     Mature 17+
# 281          3      3.90            100  Free       0     Mature 17+
# 308          8      6.50            100  Paid  $12.99       Everyone
# 327          3     22.00            100  Free       0       Everyone
# 335          6      4.90            100  Free       0     Mature 17+
# ...        ...       ...            ...   ...     ...            ...
# 9328  10484169      3.50  1,000,000,000  Free       0       Everyone
# 9335  66577313      5.30  1,000,000,000  Free       0           Teen
# 9352   2731211      4.00  1,000,000,000  Free       0       Everyone
# 9358    877635     13.00  1,000,000,000  Free       0           Teen
# 9365  27725352     76.00  1,000,000,000  Free       0   Everyone 10+
#
#                 Genres
# 212            Medical
# 281             Dating
# 308            Medical
# 327            Medical
# 335             Dating
# ...                ...
# 9328     Communication
# 9335            Social
# 9352      Productivity
# 9358  News & Magazines
# 9365            Arcade
#
# [476 rows x 10 columns]
#                                             App Category  Rating  Reviews  \
# 212                      420 BZ Budeze Delivery  MEDICAL    5.00        2
# 281                                 MouseMingle   DATING    2.70        3
# 308  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL    4.40        8
# 327                                Sway Medical  MEDICAL    5.00        3
# 335              Chat Kids - Chat Room For Kids   DATING    4.70        6
#
#      Size_MBs Installs  Type   Price Content_Rating   Genres
# 212     11.00      100  Free       0     Mature 17+  Medical
# 281      3.90      100  Free       0     Mature 17+   Dating
# 308      6.50      100  Paid  $12.99       Everyone  Medical
# 327     22.00      100  Free       0       Everyone  Medical
# 335      4.90      100  Free       0     Mature 17+   Dating

# %%
# Find the duplicate value
#  check for an individual app like ‘Instagram’ by looking up all the entries with that name in the App column.
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#             App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 9332  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 9334  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 9335  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 9336  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#      Price Content_Rating  Genres
# 9332     0           Teen  Social
# 9334     0           Teen  Social
# 9335     0           Teen  Social
# 9336     0           Teen  Social

# %%
# Remove the duplicate 
# need to specify the subset for identifying duplciates
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'])
df_apps_clean[df_apps_clean.App == 'Instagram']
# Out:
#             App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 9332  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#      Price Content_Rating  Genres
# 9332     0           Teen  Social

# %%
df_apps_clean.shape
# Out:
# (8199, 10)

# %%
# Find the highest rated app
df_apps_clean.sort_values('Rating',ascending=False).head()
# Out:
#                      App     Category  Rating  Reviews  Size_MBs Installs  \
# 0    KBA-EZ Health Guide      MEDICAL    5.00        4     25.00        1
# 326         Sway Medical      MEDICAL    5.00        3     22.00      100
# 323    AJ Men's Grooming    LIFESTYLE    5.00        2     22.00      100
# 321       FK Dedinje BGD       SPORTS    5.00       36      2.60      100
# 320      CB VIDEO VISION  PHOTOGRAPHY    5.00       13      2.60      100
#
#      Type Price Content_Rating       Genres
# 0    Free     0       Everyone      Medical
# 326  Free     0       Everyone      Medical
# 323  Free     0       Everyone    Lifestyle
# 321  Free     0       Everyone       Sports
# 320  Free     0       Everyone  Photography

# %%
# Find the app with largest size in MB
df_apps_clean.sort_values('Size_MBs',ascending=False).head(n=10)
# Out:
#                                                    App            Category  \
# 8468                    Talking Babsy Baby: Baby Games           LIFESTYLE
# 9213                            Hungry Shark Evolution                GAME
# 8469                             Miami crime simulator                GAME
# 8470                      Gangster Town: Vice District              FAMILY
# 1749                                        Vi Trainer  HEALTH_AND_FITNESS
# 8471                                   Ultimate Tennis              SPORTS
# 6452                                         Post Bank             FINANCE
# 6453                       The Walking Dead: Our World                GAME
# 6454                     Stickman Legends: Shadow Wars                GAME
# 2740  Car Crash III Beam DH Real Damage Simulator 2018                GAME
#
#       Rating  Reviews  Size_MBs     Installs  Type  Price Content_Rating  \
# 8468    4.00   140995    100.00   10,000,000  Free      0       Everyone
# 9213    4.50  6074334    100.00  100,000,000  Free      0           Teen
# 8469    4.00   254518    100.00   10,000,000  Free      0     Mature 17+
# 8470    4.30    65146    100.00   10,000,000  Free      0     Mature 17+
# 1749    3.60      124    100.00        5,000  Free      0       Everyone
# 8471    4.30   183004    100.00   10,000,000  Free      0       Everyone
# 6452    4.50    60449    100.00    1,000,000  Free      0       Everyone
# 6453    4.00    22435    100.00    1,000,000  Free      0           Teen
# 6454    4.40    38419    100.00    1,000,000  Paid  $0.99   Everyone 10+
# 2740    3.60      151    100.00       10,000  Free      0       Everyone
#
#                       Genres
# 8468  Lifestyle;Pretend Play
# 9213                  Arcade
# 8469                  Action
# 8470              Simulation
# 1749        Health & Fitness
# 8471                  Sports
# 6452                 Finance
# 6453                  Action
# 6454                  Action
# 2740                  Racing

# %%
# Find the app with highest review and check if any paid apps are included in top 50
df_apps_clean.sort_values('Reviews',ascending=False).head(n=50)
# Out:
#                                                     App            Category  \
# 9331                                           Facebook              SOCIAL
# 9311                                 WhatsApp Messenger       COMMUNICATION
# 9332                                          Instagram              SOCIAL
# 9310           Messenger – Text and Video Chat for Free       COMMUNICATION
# 9176                                     Clash of Clans                GAME
# 9270            Clean Master- Space Cleaner & Antivirus               TOOLS
# 9361                                     Subway Surfers                GAME
# 9354                                            YouTube       VIDEO_PLAYERS
# 9272  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 9110                                       Clash Royale                GAME
# 9289                                   Candy Crush Saga                GAME
# 9296        UC Browser - Fast Download Private & Secure       COMMUNICATION
# 9261                                           Snapchat              SOCIAL
# 9015    360 Security - Free Antivirus, Booster, Cleaner               TOOLS
# 9257                                     My Talking Tom                GAME
# 9120                                        8 Ball Pool                GAME
# 8828  DU Battery Saver - Battery Charger & Battery Life               TOOLS
# 8880                        BBM - Free Calls & Messages       COMMUNICATION
# 9075  Cache Cleaner-DU Speed Booster (booster & clea...               TOOLS
# 9283                                            Twitter  NEWS_AND_MAGAZINES
# 9247                                    Viber Messenger       COMMUNICATION
# 9104                                     Shadow Fight 2                GAME
# 9339                                      Google Photos         PHOTOGRAPHY
# 9250                        LINE: Free Calls & Messages       COMMUNICATION
# 9243                                                Pou                GAME
# 9318                      Skype - free IM & video calls       COMMUNICATION
# 9154                                         Pokémon GO                GAME
# 8914           Minion Rush: Despicable Me Official Game                GAME
# 9220                                            Yes day                GAME
# 9221                                            Hay Day              FAMILY
# 9170                           Dream League Soccer 2018                GAME
# 9222                                  My Talking Angela                GAME
# 9186             VivaVideo - Video Editor & Photo Movie       VIDEO_PLAYERS
# 9312                       Google Chrome: Fast & Secure       COMMUNICATION
# 9343                          Maps - Navigate & Explore    TRAVEL_AND_LOCAL
# 9198                                  Hill Climb Racing                GAME
# 9260                                      Facebook Lite              SOCIAL
# 9175                                Asphalt 8: Airborne                GAME
# 9225                          Mobile Legends: Bang Bang                GAME
# 8848  Battery Doctor-Battery Life Saver & Battery Co...               TOOLS
# 8922                                     Piano Tiles 2™                GAME
# 9303                                       Temple Run 2                GAME
# 9348                                             Google               TOOLS
# 8885  Truecaller: Caller ID, SMS spam blocking & Dialer       COMMUNICATION
# 9237                         SHAREit - Transfer & Share               TOOLS
# 8915   Sniper 3D Gun Shooter: Free Shooting Games - FPS                GAME
# 9202                                   Farm Heroes Saga                GAME
# 9102   PicsArt Photo Studio: Collage Maker & Pic Editor         PHOTOGRAPHY
# 8987  PhotoGrid: Video & Pic Collage Maker, Photo Ed...         PHOTOGRAPHY
# 9028   GO Launcher - 3D parallax Themes & HD Wallpapers     PERSONALIZATION
#
#       Rating   Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 9331    4.10  78158306      5.30  1,000,000,000  Free     0           Teen
# 9311    4.40  69119316      3.50  1,000,000,000  Free     0       Everyone
# 9332    4.50  66577313      5.30  1,000,000,000  Free     0           Teen
# 9310    4.00  56642847      3.50  1,000,000,000  Free     0       Everyone
# 9176    4.60  44891723     98.00    100,000,000  Free     0   Everyone 10+
# 9270    4.70  42916526      3.40    500,000,000  Free     0       Everyone
# 9361    4.50  27722264     76.00  1,000,000,000  Free     0   Everyone 10+
# 9354    4.30  25655305      4.65  1,000,000,000  Free     0           Teen
# 9272    4.70  24900999      3.40    500,000,000  Free     0       Everyone
# 9110    4.60  23133508     97.00    100,000,000  Free     0   Everyone 10+
# 9289    4.40  22426677     74.00    500,000,000  Free     0       Everyone
# 9296    4.50  17712922     40.00    500,000,000  Free     0           Teen
# 9261    4.00  17014787      5.30    500,000,000  Free     0           Teen
# 9015    4.60  16771865      3.40    100,000,000  Free     0       Everyone
# 9257    4.50  14891223     36.00    500,000,000  Free     0       Everyone
# 9120    4.50  14198297     52.00    100,000,000  Free     0       Everyone
# 8828    4.50  13479633     14.00    100,000,000  Free     0       Everyone
# 8880    4.30  12842860      3.50    100,000,000  Free     0       Everyone
# 9075    4.50  12759663     15.00    100,000,000  Free     0       Everyone
# 9283    4.30  11667403      6.30    500,000,000  Free     0     Mature 17+
# 9247    4.30  11334799      3.50    500,000,000  Free     0       Everyone
# 9104    4.60  10979062     88.00    100,000,000  Free     0   Everyone 10+
# 9339    4.50  10858556      6.90  1,000,000,000  Free     0       Everyone
# 9250    4.20  10790289      3.50    500,000,000  Free     0       Everyone
# 9243    4.30  10485308     24.00    500,000,000  Free     0       Everyone
# 9318    4.10  10484169      3.50  1,000,000,000  Free     0       Everyone
# 9154    4.10  10424925     85.00    100,000,000  Free     0       Everyone
# 8914    4.50  10216538     36.00    100,000,000  Free     0   Everyone 10+
# 9220    4.50  10055521     94.00    100,000,000  Free     0       Everyone
# 9221    4.50  10053186     94.00    100,000,000  Free     0       Everyone
# 9170    4.60   9882639     74.00    100,000,000  Free     0       Everyone
# 9222    4.50   9881829     99.00    100,000,000  Free     0       Everyone
# 9186    4.60   9879473     40.00    100,000,000  Free     0           Teen
# 9312    4.30   9642995      3.50  1,000,000,000  Free     0       Everyone
# 9343    4.30   9235155     12.00  1,000,000,000  Free     0       Everyone
# 9198    4.40   8923587     63.00    100,000,000  Free     0       Everyone
# 9260    4.30   8606259      5.30    500,000,000  Free     0           Teen
# 9175    4.50   8389714     92.00    100,000,000  Free     0           Teen
# 9225    4.40   8219586     99.00    100,000,000  Free     0           Teen
# 8848    4.50   8190074     17.00    100,000,000  Free     0       Everyone
# 8922    4.70   8118880     36.00    100,000,000  Free     0       Everyone
# 9303    4.30   8118609     62.00    500,000,000  Free     0       Everyone
# 9348    4.40   8033493      3.40  1,000,000,000  Free     0       Everyone
# 8885    4.50   7820209      3.50    100,000,000  Free     0       Everyone
# 9237    4.60   7790693     17.00    500,000,000  Free     0       Everyone
# 8915    4.60   7671249     36.00    100,000,000  Free     0     Mature 17+
# 9202    4.40   7614130     70.00    100,000,000  Free     0       Everyone
# 9102    4.50   7594559     34.00    100,000,000  Free     0           Teen
# 8987    4.60   7529865      6.90    100,000,000  Free     0       Everyone
# 9028    4.50   7464996      6.15    100,000,000  Free     0       Everyone
#
#                          Genres
# 9331                     Social
# 9311              Communication
# 9332                     Social
# 9310              Communication
# 9176                   Strategy
# 9270                      Tools
# 9361                     Arcade
# 9354    Video Players & Editors
# 9272                      Tools
# 9110                   Strategy
# 9289                     Casual
# 9296              Communication
# 9261                     Social
# 9015                      Tools
# 9257                     Casual
# 9120                     Sports
# 8828                      Tools
# 8880              Communication
# 9075                      Tools
# 9283           News & Magazines
# 9247              Communication
# 9104                     Action
# 9339                Photography
# 9250              Communication
# 9243                     Casual
# 9318              Communication
# 9154                  Adventure
# 8914  Casual;Action & Adventure
# 9220                     Casual
# 9221                     Casual
# 9170                     Sports
# 9222                     Casual
# 9186    Video Players & Editors
# 9312              Communication
# 9343             Travel & Local
# 9198                     Racing
# 9260                     Social
# 9175                     Racing
# 9225                     Action
# 8848                      Tools
# 8922                     Arcade
# 9303                     Action
# 9348                      Tools
# 8885              Communication
# 9237                      Tools
# 8915                     Action
# 9202                     Casual
# 9102                Photography
# 8987                Photography
# 9028            Personalization

# %%
# number of occurrences of each content rating
ratings = df_apps_clean.Content_Rating.value_counts()
ratings
# Out:
# Content_Rating
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
import plotly.express as px

#create a graph object
pie_chart = px.pie(title='Ratings Pie Chart', labels = ratings.index, values=ratings.values, names=ratings.index)

pie_chart.show()

# %%
# to configure other aspect than the parameters of .pie(), we can use .update_traces()

pie_chart = px.pie(title='Content Ratings', labels = ratings.index, values=ratings.values, names=ratings.index)

pie_chart.update_traces(textposition='outside', textinfo='percent+label')

pie_chart.show()

# %%
# create a donut chart
pie_chart = px.pie(title='Content Ratings', labels = ratings.index, values=ratings.values, names=ratings.index, hole = 0.5)

pie_chart.update_traces(textposition='inside', textfont_size=15, textinfo='percent')

pie_chart.show()

# %%
df_apps_clean.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres'],
#       dtype='object')

# %%
# Check the datatype of the Installs column
df_apps_clean.Installs.describe()
# Out:
# count          8199
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8199 entries, 0 to 9361
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.6+ KB

# %%
# number of apps at each level of installations
df_apps_clean.groupby('Installs').count().App
# Out:
# Installs
# 1                   3
# 1,000             698
# 1,000,000        1417
# 1,000,000,000      20
# 10                 69
# 10,000            988
# 10,000,000        933
# 100               303
# 100,000          1096
# 100,000,000       189
# 5                   9
# 5,000             425
# 5,000,000         607
# 50                 56
# 50,000            457
# 50,000,000        202
# 500               199
# 500,000           504
# 500,000,000        24
# Name: App, dtype: int64

# %%
# number of apps at each level of installations by removing comma
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(',', "")

# convert the Installs column data to numeric data
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)

# count the number of apps at each level
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
# C:\Users\Anuj\AppData\Local\Temp\ipykernel_1552\1414979550.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Anuj\AppData\Local\Temp\ipykernel_1552\1414979550.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %%
# Remove the $ character from price column
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace('$', "")

# convert the price column to numeric
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)

df_apps_clean[['App','Price']].sort_values('Price', ascending=False).head(n=20)
# Out:
# C:\Users\Anuj\AppData\Local\Temp\ipykernel_1552\1965085654.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Anuj\AppData\Local\Temp\ipykernel_1552\1965085654.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                  App  Price
# 2515        I'm Rich - Trump Edition 400.00
# 1163              I AM RICH PRO PLUS 399.99
# 3155               I Am Rich Premium 399.99
# 1750              I am rich(premium) 399.99
# 2143                      💎 I'm rich 399.99
# 4298                       I am rich 399.99
# 765   I am rich (Most expensive app) 399.99
# 1420                   I Am Rich Pro 399.99
# 1824                  I am Rich Plus 399.99
# 1719                       I am Rich 399.99
# 375           most expensive app (H) 399.99
# 1113                      I am Rich! 399.99
# 2470                       I Am Rich 389.99
# 957              I am extremely Rich 379.99
# 2433                   I am rich VIP 299.99
# 1027       Vargo Anesthesia Mega App  79.99
# 414                     LTC AS Legal  39.99
# 1291                I am Rich Person  37.99
# 1179         A Manual of Acupuncture  33.99
# 2824         Golfshot Plus: Golf GPS  29.99

# %%
# Remove all App the cost more than $250
df_apps_clean = df_apps_clean[df_apps_clean['Price'] < 250]
df_apps_clean.sort_values('Price', ascending=False).head()
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 1027  Vargo Anesthesia Mega App    MEDICAL    4.60       92     32.00
# 414                LTC AS Legal    MEDICAL    4.00        6      1.30
# 1291           I am Rich Person  LIFESTYLE    4.20      134      1.80
# 1179    A Manual of Acupuncture    MEDICAL    3.50      214     68.00
# 1165         PTA Content Master    MEDICAL    4.20       64     41.00
#
#       Installs  Type  Price Content_Rating     Genres
# 1027      1000  Paid  79.99       Everyone    Medical
# 414        100  Paid  39.99       Everyone    Medical
# 1291      1000  Paid  37.99       Everyone  Lifestyle
# 1179      1000  Paid  33.99       Everyone    Medical
# 1165      1000  Paid  29.99       Everyone    Medical

# %%
# Add new column 'Revenue Estimate' and Get the highest grossing paid app
df_apps_clean['Revenue Estimate'] = df_apps_clean.Installs.mul(df_apps_clean.Price)
df_apps_clean.sort_values('Revenue Estimate',ascending=False)[:10]
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 7746                      Minecraft       FAMILY    4.50  2376564     19.00
# 7351                  Hitman Sniper         GAME    4.60   408292     29.00
# 5678  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 6003            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 6503        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 5122            DraStic DS Emulator         GAME    4.60    87766     12.00
# 4611                   Weather Live      WEATHER    4.50    76593      4.75
# 6480                    Bloons TD 5       FAMILY    4.60   190086     94.00
# 6159        Five Nights at Freddy's         GAME    4.60   100805     50.00
# 5274     Card Wars - Adventure Time       FAMILY    4.30   129603     23.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# 7746  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 7351  10000000  Paid   0.99     Mature 17+                     Action
# 5678   1000000  Paid   6.99     Mature 17+                     Action
# 6003   1000000  Paid   5.99       Everyone                Photography
# 6503   1000000  Paid   5.99       Everyone                  Lifestyle
# 5122   1000000  Paid   4.99       Everyone                     Action
# 4611    500000  Paid   5.99       Everyone                    Weather
# 6480   1000000  Paid   2.99       Everyone                   Strategy
# 6159   1000000  Paid   2.99           Teen                     Action
# 5274   1000000  Paid   2.99   Everyone 10+    Card;Action & Adventure
#
#       Revenue Estimate
# 7746     69,900,000.00
# 7351      9,900,000.00
# 5678      6,990,000.00
# 6003      5,990,000.00
# 6503      5,990,000.00
# 5122      4,990,000.00
# 4611      2,995,000.00
# 6480      2,990,000.00
# 6159      2,990,000.00
# 5274      2,990,000.00

# %%
# find the number of different categories
df_apps_clean.Category.nunique()
# Out:
# 33

# %%
# Get the top 10 category based on number of apps in each category
top10_category = df_apps_clean.Category.value_counts()[:10]
top10_category
# Out:
# Category
# FAMILY             1606
# GAME                910
# TOOLS               719
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: count, dtype: int64

# %%
bar = px.bar(x = top10_category.index, y = top10_category.values)

bar.show()

# %%
# group all our apps by category and sum the number of installations
category_installs = df_apps_clean.groupby('Category').agg({'Installs' : pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

# %%
# horizontal bar
h_bar = px.bar(x = category_installs.Installs, y = category_installs.index, orientation='h', title='Category Popularity')

h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')

h_bar.show()

# %%
# Dataframe that has number of app and number of installs in the columns
cat_number = df_apps_clean.groupby('Category').agg({'App' : pd.Series.count})

# combine two dataframe
cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how='inner')

cat_merged_df.sort_values('Installs',ascending=False)
# Out:
#                       App     Installs
# Category
# GAME                  910  13858762717
# COMMUNICATION         257  11039241530
# TOOLS                 719   8099724500
# PRODUCTIVITY          301   5788070180
# SOCIAL                203   5487841475
# PHOTOGRAPHY           263   4649143130
# FAMILY               1606   4437554490
# VIDEO_PLAYERS         148   3916897200
# TRAVEL_AND_LOCAL      187   2894859300
# NEWS_AND_MAGAZINES    204   2369110650
# ENTERTAINMENT         102   2113660000
# BOOKS_AND_REFERENCE   169   1665791655
# PERSONALIZATION       298   1532352930
# SHOPPING              180   1400331540
# HEALTH_AND_FITNESS    243   1134006220
# SPORTS                260   1096431465
# BUSINESS              262    692018120
# LIFESTYLE             297    503611120
# MAPS_AND_NAVIGATION   118    503267560
# FINANCE               296    455249400
# WEATHER                72    361096500
# EDUCATION             118    352852000
# FOOD_AND_DRINK         94    211677750
# DATING                134    140912410
# ART_AND_DESIGN         61    114233100
# HOUSE_AND_HOME         62     97082000
# AUTO_AND_VEHICLES      73     53129800
# LIBRARIES_AND_DEMO     64     52083000
# COMICS                 54     44931100
# MEDICAL               292     39162676
# PARENTING              50     31116110
# BEAUTY                 42     26916200
# EVENTS                 45     15949410

# %%
#Scatter Chart
scatter = px.scatter(cat_merged_df , x='App', y='Installs', title='Category COncentration', size='App', hover_name=cat_merged_df.index, color='Installs')

# y-axis should be on a log-scale like so: yaxis=dict(type='log')
scatter.update_layout(xaxis_title = 'Number of Apps (Lower=More Concentrated)', yaxis_title='Installs', yaxis=dict(type='log'))

scatter.show()

# %%
# how many genre types are there
df_type = df_apps_clean.Genres
print(len(df_type.unique()))
# Out:
# 114

# %%
df_apps_clean.Genres.value_counts().sort_values(ascending=True)
# Out:
# Genres
# Lifestyle;Pretend Play        1
# Strategy;Education            1
# Adventure;Education           1
# Role Playing;Brain Games      1
# Tools;Education               1
#                            ...
# Personalization             298
# Productivity                301
# Education                   429
# Entertainment               467
# Tools                       718
# Name: count, Length: 114, dtype: int64

# %%
# Split the strings on the semi-colon and then .stack them.
stack = df_apps_clean.Genres.str.split(';',expand=True).stack()

print(f'We now have a single column with shape: {stack.shape}')

num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# We now have a single column with shape: (8564,)
# Number of genres: 53

# %%
bar_Chart = px.bar(x=num_genres.index[:15], y = num_genres.values[:15], title='Top Genres', hover_name=num_genres.index[:15], color = num_genres.values[:15], color_continuous_scale='Agsunset')

bar_Chart.update_layout(xaxis_title='Genre', yaxis_title='Number of Apps', coloraxis_showscale=False)
bar_Chart.show()

# %%
df_apps_clean.Type.value_counts()

#df_apps_clean.columns
# Out:
# Type
# Free    7595
# Paid     589
# Name: count, dtype: int64

# %%
df_free_vs_paid = df_apps_clean.groupby(['Category', 'Type'], as_index=False).agg({'App':pd.Series.count})

df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %%
df_apps_clean.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Revenue Estimate'],
#       dtype='object')

# %%
df_free_vs_paid.sort_values(by='App')
# Out:
#               Category  Type   App
# 3    AUTO_AND_VEHICLES  Paid     1
# 24      FOOD_AND_DRINK  Paid     2
# 38  NEWS_AND_MAGAZINES  Paid     2
# 40           PARENTING  Paid     2
# 17       ENTERTAINMENT  Paid     2
# ..                 ...   ...   ...
# 31           LIFESTYLE  Free   284
# 21             FINANCE  Free   289
# 53               TOOLS  Free   656
# 25                GAME  Free   834
# 19              FAMILY  Free  1456
#
# [61 rows x 3 columns]

# %%
grouped_bar = px.bar(df_free_vs_paid,
                     x='Category',
                     y='App',
                     title='Free vs Paid Apps by Category',
                     color='Type',
                     barmode='group')

grouped_bar.update_layout(xaxis_title='Category',
                          yaxis_title='Number of Apps',
                          xaxis={'categoryorder':'total descending'},
                          yaxis=dict(type='log'))

grouped_bar.show()

# %%
#Box plot
box_fig = px.box(df_apps_clean, x='Type', y='Installs',points='all', color='Type',title='How Many Downloads are Paid Apps Giving Up?',notched=True)
box_fig.update_layout(yaxis=dict(type='log'))

box_fig.show()

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']

box_fig_category = px.box(df_paid_apps,
                     x='Category',
                     y='Revenue Estimate',
                     title='How Much Can Paid Apps Earn?'
                    )

box_fig_category.update_layout(xaxis_title='Category',
                         yaxis_title='Paid App Ballpark Revenue',
                          xaxis={'categoryorder':'min ascending'},
                          yaxis=dict(type='log'))


box_fig_category.show()

# %%
# Compare Pricing by Category

box_fig_category = px.box(df_paid_apps,
                     x='Category',
                     y='Price',
                     title='Price Per Category'
                    )

box_fig_category.update_layout(xaxis_title='Category',
                         yaxis_title='Paid App Price',
                          xaxis={'categoryorder':'max descending'},
                          yaxis=dict(type='log'))


box_fig_category.show()

# %%
#Median price of paid android app
df_paid_apps.Price.median()
# Out:
# 2.99

# %%
# pull a random 5 samples from dataframe
df_paid_apps.sample(n=5)
# Out:
#                                      App      Category  Rating  Reviews  \
# 1581                    Tetrobot and Co.        FAMILY    4.50      709
# 3430                  Sonic 4™ Episode I          GAME    3.70     8014
# 5571                              Tasker         TOOLS    4.60    43045
# 3713  Kernel Manager for Franco Kernel ✨         TOOLS    4.80    12700
# 1307         Ad Remove Plugin for App2SD  PRODUCTIVITY    4.10       66
#
#       Size_MBs  Installs  Type  Price Content_Rating        Genres  \
# 1581     18.00      5000  Paid   2.99       Everyone        Puzzle
# 3430     37.00    100000  Paid   2.99       Everyone        Arcade
# 5571      3.40   1000000  Paid   2.99       Everyone         Tools
# 3713     10.00    100000  Paid   3.49       Everyone         Tools
# 1307      0.02      1000  Paid   1.29       Everyone  Productivity
#
#       Revenue Estimate
# 1581         14,950.00
# 3430        299,000.00
# 5571      2,990,000.00
# 3713        349,000.00
# 1307          1,290.00
